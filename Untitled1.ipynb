# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import lightkurve as lk
from lightkurve import LightCurveCollection
from lightkurve import search_lightcurvefile    
from es.saturdaysai.exoplanets.lightKurveApi.lightKurveClient import LightKurveClient

# %%
(koi_kic,t0,period,duration,mission) = (10666592,121.358542,2.204735,0.162027,'Kepler')
#(koi_kic,t0,period) = (10797460,170.538750,9.488036)

# %%
x = np.load('D:\\PERSONAL\\IA Saturdays\\saturdays_ai_exoplanets\\data\\tensors\\X_fold_00000_00005.npy', allow_pickle=True)
y = np.load('D:\\PERSONAL\\IA Saturdays\\saturdays_ai_exoplanets\\data\\tensors\\Y_fold_00000_00005.npy')
z = np.load('D:\\PERSONAL\\IA Saturdays\\saturdays_ai_exoplanets\\data\\tensors\\Z_fold_00000_00005.npy')

# %%
plt.plot(x[0][0:2049])

# %%
y[0]
# Out:
# 1

# %%
plt.plot(x[0][2049:])
